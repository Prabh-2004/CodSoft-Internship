# %% [markdown]
# # Importing the Libraries and the Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_df = pd.read_csv('advertising.csv')
raw_df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Data Discovering

# %%
raw_df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
raw_df.sort_values(by=['Sales'], ascending=False)
# Out:
#         TV  Radio  Newspaper  Sales
# 175  276.9   48.9       41.8   27.0
# 183  287.6   43.0       71.8   26.2
# 198  283.6   42.0       66.2   25.5
# 147  243.2   49.0       44.3   25.4
# 98   289.7   42.3       51.2   25.4
# ..     ...    ...        ...    ...
# 108   13.1    0.4       25.6    5.3
# 78     5.4   29.9        9.4    5.3
# 8      8.6    2.1        1.0    4.8
# 155    4.1   11.6        5.7    3.2
# 130    0.7   39.6        8.7    1.6
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Data Cleaning

# %%
# Checking for missing or duplicated values ->
print(raw_df.duplicated().sum())
print(raw_df.isna().sum())
# Out:
# 0
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# As we can see, There are no duplicated or missing values in the Dataset.

# %%
# Cheking for Outliers.
fig, axs = plt.subplots(2, 2, figsize=(9, 5))
plt1 = sns.boxplot(y=raw_df['TV'], ax=axs[0, 0])
plt2 = sns.boxplot(y=raw_df['Radio'], ax=axs[0, 1])
plt3 = sns.boxplot(y=raw_df['Newspaper'], ax=axs[1, 0])
plt3 = sns.boxplot(y=raw_df['Sales'], ax=axs[1, 1])

# plt.tight_layout()
plt.show()

# %% [markdown]
# We can conclude that, 2 outliers in Newspaper attribute do not affect the distribution of the Data and therefore have no significant impact.

# %% [markdown]
# ## Data Visualization

# %%
# Analysing the Distribution of each variable -> 
fig, axs = plt.subplots(2, 2, figsize=(10, 7))
plt1 = sns.histplot(raw_df['TV'], kde=True, ax = axs[0, 0])
plt2 = sns.histplot(raw_df['Radio'], kde=True, ax = axs[0, 1], color='red')
plt3 = sns.histplot(raw_df['Newspaper'], kde=True, ax = axs[1, 0], color='navy')
plt4 = sns.histplot(raw_df['Sales'], kde=True, ax = axs[1, 1], color='green')

plt.suptitle("Distribution of Various Attributes", fontsize=20)
plt.show()

# %%
# Figuring out the Relationship between sales and other variables ->
sns.pairplot(raw_df, x_vars=['TV', 'Radio', 'Newspaper'], y_vars='Sales', kind='scatter', height=3)
plt.show()

# %%
df = raw_df.copy()

# %%
df_corr = df.corr()

sns.heatmap(df_corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# ## Defining Inputs and the Target

# %%
# defining the inputs and the target
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]
X.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %% [markdown]
# ## Train test split

# %%
# splitting the inputs and the target into training and testing data.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=69)

# %% [markdown]
# ## Standardization

# %%
# Standardizing the inputs and the target ->
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler()

X_train = X_scaler.fit_transform(X_train)

# %% [markdown]
# # Model Training and Testing

# %%
# Accuracy Method.
from sklearn.metrics import r2_score, mean_squared_error
def accuracy(X, y, model):
    '''This Method calculates r_squared and mean_squared_error values based on 
    given inputs and target.'''
    y_pred = model.predict(X)
    rmse = np.sqrt(mean_squared_error(y_pred, y))
    r_squared = r2_score(y_pred, y)
    
    print("The R_squared value: ", r_squared)
    print("The Root Mean squared error: ", rmse)

# %%
# K-Fold Cross Validation.
from sklearn.model_selection import cross_val_score
def k_fold_cross_val(model, X, y):
    '''This Method is used to calculate the mean accuracy and the std.dev. using 
    k Fold cross validation.'''
    accuracies = cross_val_score(estimator=model, X=X, y=y, cv=10)
    print("Mean R² Score: ", (accuracies.mean()*100).round(2), "%")
    print("Standard Deviation: ", (accuracies.std()*100).round(2), "%")

# %% [markdown]
# ## Linear Regression

# %%
# Multiple Linear Regression -> 
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Training accuracy -> 
accuracy(X_train, y_train, lr)
# Out:
# The R_squared value:  0.8820698955168573
# The Root Mean squared error:  1.713212019252844

# %%
# Test Accuracy ->
X_test = X_scaler.fit_transform(X_test)

accuracy(X_test, y_test, lr)
# Out:
# The R_squared value:  0.8291020854766104
# The Root Mean squared error:  2.1037405055808662

# %%
# K-Fold Cross Validation of ten random samples ->
k_fold_cross_val(lr, X_train, y_train)
# Out:
# Mean R² Score:  87.26 %
# Standard Deviation:  6.76 %

# %%
lr.coef_
# Out:
# array([4.70623629, 1.47726139, 0.07449095])

# %%
lr.intercept_
# Out:
# 14.816875

# %% [markdown]
# ## Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree=3)
X_train_poly = poly_features.fit_transform(X_train)

pr = LinearRegression()
pr.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
# Training accuracy -> 
accuracy(X_train_poly, y_train, pr)
# Out:
# The R_squared value:  0.9334159385239722
# The Root Mean squared error:  1.3179340943740179

# %%
# Test Accuracy ->
X_test = X_scaler.fit_transform(X_test)
X_test_poly = poly_features.fit_transform(X_test)

accuracy(X_test_poly, y_test, pr)
# Out:
# The R_squared value:  0.839364503269727
# The Root Mean squared error:  2.159624218679152

# %%
# K-Fold Cross Validation of ten random samples ->
k_fold_cross_val(pr, X_train_poly, y_train)
# Out:
# Mean R² Score:  90.44 %
# Standard Deviation:  4.9 %

# %% [markdown]
# ## Support Vector Regressor

# %%
from sklearn.svm import SVR
svr = SVR(kernel='rbf')
svr.fit(X_train, y_train)
# Out:
# SVR()

# %%
# Training accuracy -> 
accuracy(X_train, y_train, svr)
# Out:
# The R_squared value:  0.8007407715588195
# The Root Mean squared error:  1.8722649936446436

# %%
# Test Accuracy ->
X_test = X_scaler.fit_transform(X_test)

accuracy(X_test, y_test, svr)
# Out:
# The R_squared value:  0.700584541676281
# The Root Mean squared error:  2.277641729163691

# %%
# K-Fold Cross Validation of ten random samples ->
k_fold_cross_val(svr, X_train, y_train)
# Out:
# Mean R² Score:  83.07 %
# Standard Deviation:  4.04 %

# %% [markdown]
# ## Decision tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor(random_state=69)
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=69)

# %%
# Training accuracy -> 
accuracy(X_train, y_train, dtr)
# Out:
# The R_squared value:  1.0
# The Root Mean squared error:  0.0

# %%
# Test Accuracy ->
X_test = X_scaler.fit_transform(X_test)

accuracy(X_test, y_test, dtr)
# Out:
# The R_squared value:  0.8883245502527293
# The Root Mean squared error:  1.8504053609952604

# %%
# K-Fold Cross Validation of ten random samples ->
k_fold_cross_val(dtr, X_train, y_train)
# Out:
# Mean R² Score:  90.6 %
# Standard Deviation:  2.57 %

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators=10, random_state=0)
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
# Training accuracy -> 
accuracy(X_train, y_train, rfr)
# Out:
# The R_squared value:  0.9873853639098409
# The Root Mean squared error:  0.5801745427024525

# %%
# Test Accuracy ->
X_test = X_scaler.fit_transform(X_test)

accuracy(X_test, y_test, rfr)
# Out:
# The R_squared value:  0.8689559467228349
# The Root Mean squared error:  1.929324363605042

# %%
# K-Fold Cross Validation of ten random samples ->
k_fold_cross_val(rfr, X_train, y_train)
# Out:
# Mean R² Score:  93.23 %
# Standard Deviation:  2.79 %

# %% [markdown]
# # Conclusions
# #### Linear Regression
# - Accumulative R² Score: 87.26%
# #### Polynomial Regression
# - Accumulative R² Score: 90.44%
# #### Support Vector Regressor
# - Accumulative R² Score: 83.07%
# #### Decision Tree Regressor
# - Accumulative R² Score: 90.69%
# #### Random Forest Regressor
# - Accumulative R² Score: 93.23%
#
# `Random Forest Regressor has the best performance`

# %%
plt.scatter(x=y_test, y=rfr.predict(X_test))

# %% [markdown]
# ## <h1 align='center'>Thank You!</h1>
